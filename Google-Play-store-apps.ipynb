# %% [markdown]
# <img src = "https://www.cyclonis.com/images/2020/03/googleplay.jpg" width=50%>

# %% [markdown]
# ## Importing the libraries

# %%
import string
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# ## Load and Prepare Data

# %%
before_drop = pd.read_csv("googleplaystore.csv")

# %%
type(before_drop)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## EDA

# %%
before_drop.shape
# Out:
# (10841, 13)

# %%
drop_df = before_drop.drop_duplicates()
drop_df.shape
# Out:
# (10358, 13)

# %%
drop_df = drop_df.drop_duplicates(subset=["App"])
drop_df.shape
# Out:
# (9660, 13)

# %%
drop_df.to_csv('data_pg.csv', index=True)

# %%
data_gp = pd.read_csv("data_pg.csv")

# %%
data_gp
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9655       10836                                   Sya9a Maroc - FR
# 9656       10837                   Fr. Mike Schmitz Audio Teachings
# 9657       10838                             Parkinson Exercices FR
# 9658       10839                      The SCP Foundation DB fr nn5n
# 9659       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating Reviews                Size     Installs  \
# ...

# %%
data_gp.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1     159   19M      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9     967   14M     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7   87510  8.7M   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5  215644   25M  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3     967  2.8M     100,000+  Free     0
#
#   Content Rating                     Genres      Last Updated  \
# 0       Everyone               Art & Design   January 7, 2018
# ...

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9660 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9660 non-null   int64
#  1   App             9660 non-null   object
#  2   Category        9660 non-null   object
#  3   Rating          8197 non-null   float64
#  4   Reviews         9660 non-null   object
#  5   Size            9660 non-null   object
#  6   Installs        9660 non-null   object
#  7   Type            9659 non-null   object
#  8   Price           9660 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9660 non-null   object
#  11  Last Updated    9660 non-null   object
#  12  Current Ver     9652 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 1.0+ MB

# %%
data_gp.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
# column 2
data_gp['Category'].value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# ART_AND_DESIGN           64
# EVENTS                   64
# PARENTING                60
# COMICS                   56
# ...

# %%
row = np.where(data_gp['Category'] == '1.9')
print(row)
# Out:
# (array([9300], dtype=int64),)

# %%
data_gp.iloc[9300,2]
# Out:
# '1.9'

# %%
data_gp[9300:9301]
# Out:
#       Unnamed: 0                                      App Category  Rating  \
# 9300       10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0
#
#      Reviews    Size Installs Type     Price Content Rating  \
# 9300    3.0M  1,000+     Free    0  Everyone            NaN
#
#                  Genres Last Updated Current Ver Android Ver
# 9300  February 11, 2018       1.0.19  4.0 and up         NaN

# %%
# data_gp.at[9300, 1] = 'None'
data_gp = data_gp.drop(9300)

# %%
data_gp['Category'].dtype
# Out:
# dtype('O')

# %%
# column 2
data_gp['Category'].value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %%
# column 3
data_gp['Rating'].dtype
# Out:
# dtype('float64')

# %%
data_gp['Rating']
# Out:
# 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 9655    4.5
# 9656    5.0
# 9657    NaN
# 9658    4.5
# 9659    4.5
# Name: Rating, Length: 9659, dtype: float64

# %%
data_gp['Rating'] = data_gp['Rating'].astype('float32')

# %%
data_gp['Rating'].dtype
# Out:
# dtype('float32')

# %%
data_gp['Rating']
# Out:
# 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 9655    4.5
# 9656    5.0
# 9657    NaN
# 9658    4.5
# 9659    4.5
# Name: Rating, Length: 9659, dtype: float32

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   object
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   object
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(1), int64(1), object(12)
# memory usage: 1.1+ MB

# %%
data_gp
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9655       10836                                   Sya9a Maroc - FR
# 9656       10837                   Fr. Mike Schmitz Audio Teachings
# 9657       10838                             Parkinson Exercices FR
# 9658       10839                      The SCP Foundation DB fr nn5n
# 9659       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating Reviews                Size     Installs  \
# ...

# %%
# column 4
data_gp['Reviews'].value_counts()
# Out:
# Reviews
# 0         593
# 1         272
# 2         213
# 3         170
# 4         137
#          ...
# 157506      1
# 351254      1
# 49211       1
# 88860       1
# 398307      1
# Name: count, Length: 5330, dtype: int64

# %%
reviews_list = [ int(i) for i in data_gp.Reviews]
max(reviews_list)
# Out:
# 78158306

# %%
data_gp['Reviews'] = data_gp['Reviews'].astype('int32')

# %%
reviews_list = [ int(i) for i in data_gp.Reviews]
max(reviews_list)
# Out:
# 78158306

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   object
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(1), int32(1), int64(1), object(11)
# memory usage: 1.0+ MB

# %%
data_gp['Reviews']
# Out:
# 0          159
# 1          967
# 2        87510
# 3       215644
# 4          967
#          ...
# 9655        38
# 9656         4
# 9657         3
# 9658       114
# 9659    398307
# Name: Reviews, Length: 9659, dtype: int32

# %%
# column 5
data_gp['Size'].value_counts()
# Out:
# Size
# Varies with device    1227
# 11M                    182
# 12M                    181
# 14M                    177
# 13M                    177
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: count, Length: 461, dtype: int64

# %%
# column 6
data_gp['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1417
# 100,000+          1112
# 10,000+           1031
# 10,000,000+        937
# 1,000+             888
# 100+               710
# 5,000,000+         607
# 500,000+           505
# 50,000+            469
# 5,000+             468
# 10+                385
# 500+               328
# 50+                204
# 50,000,000+        202
# 100,000,000+       188
# 5+                  82
# 1+                  67
# 500,000,000+        24
# 1,000,000,000+      20
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
install_list = [int(item.replace(',', '').replace('+', '')) for item in data_gp.Installs]

# %%
max(install_list)
# Out:
# 1000000000

# %%
data_gp.loc[:, 'Installs'] = install_list

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   object
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(1), int32(1), int64(1), object(11)
# memory usage: 1.0+ MB

# %%
data_gp['Installs'] = data_gp['Installs'].astype('int32')

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   int32
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(1), int32(2), int64(1), object(10)
# memory usage: 1018.7+ KB

# %%
data_gp['Installs']
# Out:
# 0          10000
# 1         500000
# 2        5000000
# 3       50000000
# 4         100000
#           ...
# 9655        5000
# 9656         100
# 9657        1000
# 9658        1000
# 9659    10000000
# Name: Installs, Length: 9659, dtype: int32

# %%
# column 7
data_gp['Type'].value_counts()
# Out:
# Type
# Free    8902
# Paid     756
# Name: count, dtype: int64

# %%
# column 8
data_gp['Price'].value_counts()
# Out:
# Price
# 0          8903
# $0.99       145
# $2.99       124
# $1.99        73
# $4.99        70
#            ...
# $18.99        1
# $389.99       1
# $19.90        1
# $1.75         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
price_list = [float(item.replace('$','')) if item[0]=="$" else item for item in data_gp.Price]

# %%
indices_of_none = [index for index, value in enumerate(price_list) if value is None]
print(indices_of_none)
# Out:
# []

# %%
data_gp.loc[:, 'Price'] = price_list

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   int32
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(1), int32(2), int64(1), object(10)
# memory usage: 1018.7+ KB

# %%
data_gp['Price'] = data_gp['Price'].astype('float32')

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   int32
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   float32
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(2), int32(2), int64(1), object(9)
# memory usage: 981.0+ KB

# %%
# column 9
data_gp['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           7903
# Teen               1036
# Mature 17+          393
# Everyone 10+        322
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
# column 10
data_gp['Genres'].value_counts()
# Out:
# Genres
# Tools                              826
# Entertainment                      561
# Education                          510
# Business                           420
# Medical                            395
#                                   ...
# Art & Design;Pretend Play            1
# Lifestyle;Pretend Play               1
# Comics;Creativity                    1
# Art & Design;Action & Adventure      1
# Strategy;Creativity                  1
# Name: count, Length: 118, dtype: int64

# %%
# column 11
data_gp['Last Updated'].value_counts()
# Out:
# Last Updated
# August 3, 2018      252
# August 2, 2018      230
# August 1, 2018      209
# July 31, 2018       204
# July 30, 2018       160
#                    ...
# March 8, 2015         1
# March 25, 2015        1
# July 9, 2014          1
# October 11, 2014      1
# March 23, 2014        1
# Name: count, Length: 1377, dtype: int64

# %%
reviews_list = [i for i in data_gp['Last Updated']]
for index, item in enumerate(reviews_list):
    if all(',' not in part for part in item):
        print(f"Index of item without comma: {index} and the item is: {item}")

# %%
# column 12
data_gp['Current Ver'].value_counts()
# Out:
# Current Ver
# Varies with device    1055
# 1.0                    799
# 1.1                    260
# 1.2                    176
# 2.0                    149
#                       ...
# 2.27.1                   1
# 1.6.11                   1
# 20180517                 1
# 3.1.00                   1
# 2.0.148.0                1
# Name: count, Length: 2817, dtype: int64

# %%
# column 13
data_gp['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1 and up            2202
# 4.0.3 and up          1395
# 4.0 and up            1285
# Varies with device     990
# 4.4 and up             818
# 2.3 and up             616
# 5.0 and up             512
# 4.2 and up             372
# 2.3.3 and up           273
# 2.2 and up             239
# 3.0 and up             231
# 4.3 and up             221
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              54
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
data_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   int32
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   float32
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(2), int32(2), int64(1), object(9)
# memory usage: 981.0+ KB

# %%
data_gp_clean = data_gp.copy()

# %%
data_gp_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 9659
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float32
#  4   Reviews         9659 non-null   int32
#  5   Size            9659 non-null   object
#  6   Installs        9659 non-null   int32
#  7   Type            9658 non-null   object
#  8   Price           9659 non-null   float32
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float32(2), int32(2), int64(1), object(9)
# memory usage: 981.0+ KB

# %%
pd.crosstab(data_gp_clean.Type, data_gp_clean['Content Rating'] )
# Out:
# Content Rating  Adults only 18+  Everyone  Everyone 10+  Mature 17+  Teen  \
# Type
# Free                          3      7248           290         375   984
# Paid                          0       655            31          18    52
#
# Content Rating  Unrated
# Type
# Free                  2
# Paid                  0

# %%
pd.crosstab(data_gp_clean.Type, data_gp_clean['Content Rating'], normalize = "columns" )
# Out:
# Content Rating  Adults only 18+  Everyone  Everyone 10+  Mature 17+      Teen  \
# Type
# Free                        1.0   0.91712      0.903427    0.954198  0.949807
# Paid                        0.0   0.08288      0.096573    0.045802  0.050193
#
# Content Rating  Unrated
# Type
# Free                1.0
# Paid                0.0

# %% [markdown]
# ## Data Preprocessing

# %%
data_gp_clean.Rating.unique
# Out:
# <bound method Series.unique of 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 9655    4.5
# 9656    5.0
# 9657    NaN
# 9658    4.5
# 9659    4.5
# Name: Rating, Length: 9659, dtype: float32>

# %%
data_gp_clean.Rating.info
# Out:
# <bound method Series.info of 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 9655    4.5
# 9656    5.0
# 9657    NaN
# 9658    4.5
# 9659    4.5
# Name: Rating, Length: 9659, dtype: float32>

# %%
data_gp_clean[ (data_gp_clean.Rating >=4.7) ]
# Out:
#       Unnamed: 0                                                App  \
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 9              9                      Kids Paint Free - Drawing Fun
# 16            16       Photo Designer - Write your name with shapes
# 22            22            Superheroes Wallpapers | 4K Backgrounds
# 24            24                        HD Mickey Minnie Wallpapers
# ...          ...                                                ...
# 9628       10809              Castle Clash: RPG War and Strategy FR
# 9629       10810                                  Fr Lupupa Sermons
# 9639       10820                                    Fr. Daoud Lamei
# 9652       10833                                        Chemin (fr)
# 9656       10837                   Fr. Mike Schmitz Audio Teachings
#
#                  Category  Rating  Reviews  Size  Installs  Type  Price  \
# 2          ART_AND_DESIGN     4.7    87510  8.7M   5000000  Free    0.0
# ...

# %%
data_gp_clean[ (data_gp_clean['Content Rating'] =='Everyone') ]
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 4              4              Pixel Draw - Number Art Coloring Book
# 5              5                         Paper flowers instructions
# ...          ...                                                ...
# 9654       10835                                           FR Forms
# 9655       10836                                   Sya9a Maroc - FR
# 9656       10837                   Fr. Mike Schmitz Audio Teachings
# 9657       10838                             Parkinson Exercices FR
# 9659       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#             Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0     ART_AND_DESIGN     4.1      159   19M     10000  Free    0.0
# ...

# %%
reviews_list = [i for i in data_gp_clean.Reviews]

# %%
Review_over_10M_index = [index for index, value in enumerate(reviews_list) if value > 10000000]
data_gp_clean.iloc[Review_over_10M_index]
# Out:
#       Unnamed: 0                                                App  \
# 299          335           Messenger – Text and Video Chat for Free
# 300          336                                 WhatsApp Messenger
# 306          342                                    Viber Messenger
# 342          378        UC Browser - Fast Download Private & Secure
# 349          391                      Skype - free IM & video calls
# 357          403                        LINE: Free Calls & Messages
# 360          406                        BBM - Free Calls & Messages
# 1356        1654                                     Subway Surfers
# 1357        1655                                   Candy Crush Saga
# 1362        1660                                       Clash Royale
# 1364        1662                                                Pou
# 1372        1670                                     Clash of Clans
# 1377        1675                                        8 Ball Pool
# ...

# %%
install_list = [i for i in data_gp_clean.Installs]
install_lists= [index for index, value in enumerate(install_list) if value >= 1000000000]
data_gp_clean.iloc[install_lists]
# Out:
#       Unnamed: 0                                       App  \
# 152          152                         Google Play Books
# 299          335  Messenger – Text and Video Chat for Free
# 300          336                        WhatsApp Messenger
# 302          338              Google Chrome: Fast & Secure
# 304          340                                     Gmail
# 305          341                                  Hangouts
# 349          391             Skype - free IM & video calls
# 701          865                         Google Play Games
# 1356        1654                            Subway Surfers
# 2002        2544                                  Facebook
# 2003        2545                                 Instagram
# 2012        2554                                   Google+
# 2191        2808                             Google Photos
# 2420        3117                 Maps - Navigate & Explore
# 2429        3127                        Google Street View
# ...

# %%
installs_over_1B_index= [index for index, value in enumerate(install_list) if value >= 1000000000]

# %%
data_gp_clean.iloc[installs_over_1B_index][['App','Installs','Content Rating','Rating','Genres']]
# Out:
#                                            App    Installs Content Rating  \
# 152                          Google Play Books  1000000000           Teen
# 299   Messenger – Text and Video Chat for Free  1000000000       Everyone
# 300                         WhatsApp Messenger  1000000000       Everyone
# 302               Google Chrome: Fast & Secure  1000000000       Everyone
# 304                                      Gmail  1000000000       Everyone
# 305                                   Hangouts  1000000000       Everyone
# 349              Skype - free IM & video calls  1000000000       Everyone
# 701                          Google Play Games  1000000000           Teen
# 1356                            Subway Surfers  1000000000   Everyone 10+
# 2002                                  Facebook  1000000000           Teen
# 2003                                 Instagram  1000000000           Teen
# 2012                                   Google+  1000000000           Teen
# ...

# %%
io1bi=installs_over_1B_index

# %%
(data_gp_clean.iloc[io1bi])[((data_gp_clean.iloc[io1bi])["Content Rating"] == 'Teen') & ((data_gp_clean.iloc[io1bi]).Rating >= 4.5)]
# Out:
#       Unnamed: 0        App Category  Rating   Reviews                Size  \
# 2003        2545  Instagram   SOCIAL     4.5  66577313  Varies with device
#
#         Installs  Type  Price Content Rating  Genres   Last Updated  \
# 2003  1000000000  Free    0.0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2003  Varies with device  Varies with device

# %%
Last_Updated_list = [int( i[-4:]) for i in data_gp_clean['Last Updated']]
update_before_2012 = [index for index, value in enumerate(Last_Updated_list) if  2000 <value < 2012]

# %%
data_gp_clean.iloc[update_before_2012]
# Out:
#       Unnamed: 0                        App             Category  Rating  \
# 1256        1544              Apk Installer   LIBRARIES_AND_DEMO     3.8
# 3537        4439               Band O'Clock            LIFESTYLE     3.8
# 4193        5144             AH Alarm Panel                TOOLS     3.9
# 4590        5561               Satellite AR  BOOKS_AND_REFERENCE     4.1
# 6037        7080                     Bubble                TOOLS     4.5
# 6193        7237               CF-Bench Pro                TOOLS     4.6
# 6383        7430   CJ Poker Odds Calculator                 GAME     4.1
# 6430        7479  FML F*ck my life + widget               FAMILY     4.2
# 6438        7487   CONTRACT KILLER: ZOMBIES                 GAME     4.4
# 7018        8084                Freecell CY                 GAME     4.0
# 7127        8200                 DB Browser                TOOLS     3.3
# 7332        8418      DEER HUNTER CHALLENGE                 GAME     3.7
# ...

# %%
(data_gp_clean.iloc[update_before_2012])[((data_gp_clean.iloc[update_before_2012]).Price !=0)]
# Out:
#       Unnamed: 0                      App Category  Rating  Reviews Size  \
# 4193        5144           AH Alarm Panel    TOOLS     3.9        7  81k
# 6193        7237             CF-Bench Pro    TOOLS     4.6      159  29k
# 9288       10460  Wi-Fi Rabbit Unlock Key    TOOLS     4.5      142  26k
#
#       Installs  Type  Price Content Rating Genres   Last Updated Current Ver  \
# 4193       100  Paid   4.99       Everyone  Tools   May 12, 2011       1.2.0
# 6193      1000  Paid   1.49       Everyone  Tools  June 23, 2011         1.1
# 9288      5000  Paid   1.00       Everyone  Tools  June 26, 2011       1.0.0
#
#      Android Ver
# 4193  1.5 and up
# 6193  1.6 and up
# 9288  2.1 and up

# %% [markdown]
# ## Strorytelling - Visualization

# %%
import warnings
warnings.filterwarnings('ignore')
sns.histplot(data_gp_clean, x='Rating', bins=10, binrange=(0, 5))
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(data_gp_clean, x='Content Rating')
plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(data_gp_clean, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Count'>

# %%
install_list = [i for i in data_gp_clean.Installs]

# %%
data_gp_1 = data_gp_clean.copy()
data_gp_1.loc[:, 'Installs'] = install_list

# %%
sns.catplot(data=data_gp_1, x='Installs',  y='Content Rating', kind='boxen', palette=sns.color_palette(),height=7, aspect=2 )

# %%
L = [i for i in data_gp_clean['Last Updated']]
update_2016_Dec_index= [index for index, value in enumerate(L) if value[:3]== 'Dec' and value[-4:] == '2016']
update_2016_Dec = data_gp.iloc[update_2016_Dec_index]

# %%
sns.set_theme(style="darkgrid" )
sns.relplot(x='Genres', y='Rating' , hue='Type', data=update_2016_Dec,height=5, aspect=3 )
plt.xticks(rotation=90)
plt.show()

# %%
L = [i for i in data_gp_clean['Last Updated']]
update_2018_June_index= [index for index, value in enumerate(L) if value[:4]== 'June' and value[-4:] == '2018']
# len(update_2017_June_index)
update_2018_June = data_gp_clean.iloc[update_2018_June_index]

# %%
sns.displot(x="Rating", kind="hist", hue="Type", data=update_2018_June)
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(data_gp_clean, x='Rating')

# %%
data_gp_year = data_gp_clean.copy()

# %%
data_gp_year['Last Updated'] = data_gp_year['Last Updated'].apply(lambda x: int(x.split(',')[-1]))

# %%
sns.displot(data_gp_year, x='Last Updated')

# %%
sns.relplot(x="Last Updated", y="Rating", data=data_gp_year)

# %%
sns.relplot(x="Last Updated", y="Installs", kind="line", data=data_gp_year)

# %%
sns.relplot(x="Last Updated", y="Installs", hue="Type", data=data_gp_year, palette=sns.color_palette("pastel") )

# %%
L2 = [i for i in data_gp_clean['Last Updated']]
update_2018_index= [index for index, value in enumerate(L2) if  value[-4:] == '2018']
update_2018 = data_gp_clean.iloc[update_2018_index]

# %%
update_2018['Last Updated'] = update_2018['Last Updated'].apply(lambda x: x.split(' ')[0])

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
update_2018['Last Updated'] = pd.Categorical(update_2018['Last Updated'], categories=month_order, ordered=True)

# %%
sns.relplot(x="Last Updated", y="Installs", kind="line", data=update_2018)
plt.xticks(rotation=90)
plt.show()

# %%
sns.relplot(x="Last Updated", y="Rating", data=update_2018)
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(update_2018, x='Last Updated', shrink=0.8, bins=12)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=update_2018, x='Last Updated')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x="Last Updated", y="Rating", data=update_2018 , palette=sns.color_palette())
plt.xticks(rotation=90)
plt.show()

# %%
sns.regplot(x="Price", y="Rating", data=update_2018)
plt.xticks(rotation=90)
plt.show()

# %%
L3 = [i for i in data_gp_clean['Last Updated']]
update_2017_index= [index for index, value in enumerate(L3) if  value[-4:] == '2017']
update_2017 = data_gp_clean.iloc[update_2017_index]

# %%
update_2017['Last Updated'] = update_2017['Last Updated'].apply(lambda x: x.split(' ')[0])

# %%
update_2017['Last Updated'] = pd.Categorical(update_2017['Last Updated'], categories=month_order, ordered=True)

# %%
sns.catplot(x="Last Updated", y="Rating", kind="swarm", data=update_2017 , palette=sns.color_palette("rocket"), height=4, aspect=2)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=update_2017, x='Last Updated')
plt.xticks(rotation=90)
plt.show()

# %%
sns.regplot(x="Price", y="Rating", data=update_2017)
plt.xticks(rotation=90)
plt.show()

# %%
L4 = [i for i in data_gp_clean['Last Updated']]
update_2015_index= [index for index, value in enumerate(L4) if  value[-4:] == '2015']
update_2015 = data_gp_clean.iloc[update_2015_index]

# %%
update_2015['Last Updated'] = update_2015['Last Updated'].apply(lambda x: x.split(' ')[0])

# %%
update_2015['Last Updated'] = pd.Categorical(update_2015['Last Updated'], categories=month_order, ordered=True)

# %%
sns.countplot(data=update_2015, x='Last Updated')
plt.xticks(rotation=90)
plt.show()

# %%
sns.regplot(x="Price", y="Rating", data=update_2015)
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x="Price", y="Rating", kind="swarm", data=update_2015 , palette=sns.color_palette("rocket"), height=4, aspect=2)
plt.xticks(rotation=90)
plt.show()
